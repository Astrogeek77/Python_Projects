# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Practice.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pandas.read_json('supermarkets.json')
df2.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
import sys
# !{sys.executable} -m pip install openpyxl

# %%
df3 = pandas.read_excel('supermarkets.xlsx', sheet_name = 0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=';')
df5.set_index('ID')
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6 = df5.loc["2":"4", "City":"Country"]
df6
# Out:
#             City             State Country
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA
# 4  San Francisco        California     USA

# %%
df7 = df5.loc[:, "City":"Country"]
df7
# Out:
#             City             State Country
# 0  San Francisco          CA 94114     USA
# 1  San Francisco          CA 94119     USA
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA
# 4  San Francisco        California     USA
# 5  San Francisco          CA 94114     USA

# %%
df8 = df5.iloc[1:4, 1:4]
df8
# Out:
#           Address           City             State
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114
# 3    3995 23rd St  San Francisco          CA 94114

# %%
import sys
# !{sys.executable} -m pip install geopy

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
nom.geocode("4184 3rd St, New Madhopuri, Ludhiana")
# Out:
# Location(4184 Street No 3, New Madhopuri, Ludhiana, Punjab, 141008, (30.91912998395, 75.86812997975764, 0.0))

# %%
MyHome = nom.geocode("4184 3rd St, New Madhopuri, Ludhiana")

# %%
MyHome
# Out:
# Location(4184 Street No 3, New Madhopuri, Ludhiana, Punjab, 141008, (30.91912998395, 75.86812997975764, 0.0))

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1['Address'] = df1['Address'] + ', ' + df1['City'] + df1['State']

# %%
df1
# Out:
#    ID                                     Address           City  \
# 0   1         3666 21st St, San FranciscoCA 94114  San Francisco
# 1   2       735 Dolores St, San FranciscoCA 94119  San Francisco
# 2   3  332 Hill St, San FranciscoCalifornia 94114  San Francisco
# 3   4         3995 23rd St, San FranciscoCA 94114  San Francisco
# 4   5    1056 Sanchez St, San FranciscoCalifornia  San Francisco
# 5   6      551 Alvarado St, San FranciscoCA 94114  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df1['Address'] = df1['Address'] + ', ' + df1['City'] + ', ' + df1['State']

# %%
df1.set_index('ID')
df1['Address'] = df1['Address'] + ', ' + df1['City'] + ', ' + df1['State'] + ', ' + df1['Country']
df1.set_index('ID', inplace=True)
# Out:
#                                               Address           City  \
# ID
# 1   3666 21st St, San FranciscoCA 94114, San Franc...  San Francisco
# 2   735 Dolores St, San FranciscoCA 94119, San Fra...  San Francisco
# 3   332 Hill St, San FranciscoCalifornia 94114, Sa...  San Francisco
# 4   3995 23rd St, San FranciscoCA 94114, San Franc...  San Francisco
# 5   1056 Sanchez St, San FranciscoCalifornia, San ...  San Francisco
# 6   551 Alvarado St, San FranciscoCA 94114, San Fr...  San Francisco
#
#                State Country         Name  Employees
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20

# %%
df1
# Out:
#                                               Address           City  \
# ID
# 1   3666 21st St, San FranciscoCA 94114, San Franc...  San Francisco
# 2   735 Dolores St, San FranciscoCA 94119, San Fra...  San Francisco
# 3   332 Hill St, San FranciscoCalifornia 94114, Sa...  San Francisco
# 4   3995 23rd St, San FranciscoCA 94114, San Franc...  San Francisco
# 5   1056 Sanchez St, San FranciscoCalifornia, San ...  San Francisco
# 6   551 Alvarado St, San FranciscoCA 94114, San Fr...  San Francisco
#
#                State Country         Name  Employees
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20

# %%
df1['Coordinates'] = df1['Address'].apply(nom.geocode)
df1
# Out:
# ---------------------------------------------------------------------------
# GeocoderServiceError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15784/42891790.py in <module>
# ----> 1 df1['Coordinates'] = df1['Address'].apply(nom.geocode)
#       2 df1
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
df1
# Out:
#                                               Address           City  \
# ID
# 1   3666 21st St, San FranciscoCA 94114, San Franc...  San Francisco
# 2   735 Dolores St, San FranciscoCA 94119, San Fra...  San Francisco
# 3   332 Hill St, San FranciscoCalifornia 94114, Sa...  San Francisco
# 4   3995 23rd St, San FranciscoCA 94114, San Franc...  San Francisco
# 5   1056 Sanchez St, San FranciscoCalifornia, San ...  San Francisco
# 6   551 Alvarado St, San FranciscoCA 94114, San Fr...  San Francisco
#
#                State Country         Name  Employees
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20

# %%
MyHome
# Out:
# Location(4184 Street No 3, New Madhopuri, Ludhiana, Punjab, 141008, (30.91912998395, 75.86812997975764, 0.0))

# %%
for row in df1:
    Address = row[1]

# %%
Address
# Out:
# 'm'
